# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, recall_score, f1_score, precision_score, roc_auc_score
import pandas as pd
import numpy as np

dataset = pd.read_csv('phishing.csv')
features = np.array(dataset.iloc[:, 1:-1].values)
label = np.array(dataset.iloc[:, -1].values)

x_train, x_test, y_train, y_test = train_test_split(features, label, test_size=0.2, shuffle=True, random_state=156)

# #애림님 : 0.94...
# #트리개수는 400개로 지정
# lgbm_wrapper = LGBMClassifier(n_estimaors =400)
# evals = [(x_test, y_test)]
# lgbm_wrapper.fit(x_train, y_train, early_stopping_rounds= 100, eval_metric='logloss',
#                 eval_set =evals, verbose = True)
# preds = lgbm_wrapper.predict(x_test)
# accuracy = accuracy_score(y_test, preds)
# precision = precision_score(y_test, preds)
# AUC = roc_auc_score(y_test, preds)
# print('\n정확도: {:.4f}'.format(accuracy))
# print('정밀도: {:.4f}'.format(precision))
# print('AUC: {:.4f}'.format(AUC))

# # 지연님 : 0.94...
# clf = LGBMClassifier(boosting_type='gbdt', learning_rate=0.03, 
#                n_estimators=400, objective='binary', metric='binary_logloss')
# clf.fit(x_train, y_train)
# y_pred = clf.predict(x_test)
# #accuracy : normalize=True이면 올바르게 분류된 데이터 비율 출력
# print(accuracy_score(y_test, y_pred, normalize=True))
# Out:
# [1]	valid_0's binary_logloss: 0.609573
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.552624
# [3]	valid_0's binary_logloss: 0.505376
# [4]	valid_0's binary_logloss: 0.465086
# [5]	valid_0's binary_logloss: 0.431011
# [6]	valid_0's binary_logloss: 0.401006
# [7]	valid_0's binary_logloss: 0.375333
# [8]	valid_0's binary_logloss: 0.35301
# [9]	valid_0's binary_logloss: 0.333018
# [10]	valid_0's binary_logloss: 0.315717
# [11]	valid_0's binary_logloss: 0.300535
# [12]	valid_0's binary_logloss: 0.287241
# [13]	valid_0's binary_logloss: 0.2752
# [14]	valid_0's binary_logloss: 0.264866
# [15]	valid_0's binary_logloss: 0.255593
# [16]	valid_0's binary_logloss: 0.247021
# [17]	valid_0's binary_logloss: 0.239225
# [18]	valid_0's binary_logloss: 0.232111
# [19]	valid_0's binary_logloss: 0.225782
# [20]	valid_0's binary_logloss: 0.220181
# [21]	valid_0's binary_logloss: 0.215196
# [22]	valid_0's binary_logloss: 0.210674
# [23]	valid_0's binary_logloss: 0.206618
# [24]	valid_0's binary_logloss: 0.201647
# [25]	valid_0's binary_logloss: 0.197739
# [26]	valid_0's binary_logloss: 0.194084
# [27]	valid_0's binary_logloss: 0.19138
# [28]	valid_0's binary_logloss: 0.188494
# [29]	valid_0's binary_logloss: 0.185589
# [30]	valid_0's binary_logloss: 0.183151
# [31]	valid_0's binary_logloss: 0.180642
# [32]	valid_0's binary_logloss: 0.178334
# [33]	valid_0's binary_logloss: 0.17631
# [34]	valid_0's binary_logloss: 0.174572
# [35]	valid_0's binary_logloss: 0.172832
# [36]	valid_0's binary_logloss: 0.171031
# [37]	valid_0's binary_logloss: 0.169323
# [38]	valid_0's binary_logloss: 0.167879
# [39]	valid_0's binary_logloss: 0.166577
# [40]	valid_0's binary_logloss: 0.165315
# [41]	valid_0's binary_logloss: 0.163959
# [42]	valid_0's binary_logloss: 0.162768
# [43]	valid_0's binary_logloss: 0.161685
# [44]	valid_0's binary_logloss: 0.160644
# [45]	valid_0's binary_logloss: 0.159675
# [46]	valid_0's binary_logloss: 0.158783
# [47]	valid_0's binary_logloss: 0.157939
# [48]	valid_0's binary_logloss: 0.157148
# [49]	valid_0's binary_logloss: 0.156426
# [50]	valid_0's binary_logloss: 0.155571
# [51]	valid_0's binary_logloss: 0.154829
# [52]	valid_0's binary_logloss: 0.154216
# [53]	valid_0's binary_logloss: 0.153422
# [54]	valid_0's binary_logloss: 0.15279
# [55]	valid_0's binary_logloss: 0.1522
# [56]	valid_0's binary_logloss: 0.151531
# [57]	valid_0's binary_logloss: 0.15107
# [58]	valid_0's binary_logloss: 0.150648
# [59]	valid_0's binary_logloss: 0.150058
# [60]	valid_0's binary_logloss: 0.149661
# [61]	valid_0's binary_logloss: 0.149286
# [62]	valid_0's binary_logloss: 0.148849
# [63]	valid_0's binary_logloss: 0.148593
# [64]	valid_0's binary_logloss: 0.148072
# [65]	valid_0's binary_logloss: 0.147672
# [66]	valid_0's binary_logloss: 0.147251
# [67]	valid_0's binary_logloss: 0.146971
# [68]	valid_0's binary_logloss: 0.146749
# [69]	valid_0's binary_logloss: 0.146314
# [70]	valid_0's binary_logloss: 0.14594
# [71]	valid_0's binary_logloss: 0.145631
# [72]	valid_0's binary_logloss: 0.145332
# [73]	valid_0's binary_logloss: 0.145073
# [74]	valid_0's binary_logloss: 0.144885
# [75]	valid_0's binary_logloss: 0.144699
# [76]	valid_0's binary_logloss: 0.144369
# [77]	valid_0's binary_logloss: 0.144174
# [78]	valid_0's binary_logloss: 0.14397
# [79]	valid_0's binary_logloss: 0.14371
# [80]	valid_0's binary_logloss: 0.143525
# [81]	valid_0's binary_logloss: 0.143448
# [82]	valid_0's binary_logloss: 0.14322
# [83]	valid_0's binary_logloss: 0.142985
# [84]	valid_0's binary_logloss: 0.14276
# [85]	valid_0's binary_logloss: 0.142644
# [86]	valid_0's binary_logloss: 0.142599
# [87]	valid_0's binary_logloss: 0.142308
# [88]	valid_0's binary_logloss: 0.142079
# [89]	valid_0's binary_logloss: 0.141934
# [90]	valid_0's binary_logloss: 0.141629
# [91]	valid_0's binary_logloss: 0.141465
# [92]	valid_0's binary_logloss: 0.141304
# [93]	valid_0's binary_logloss: 0.141154
# [94]	valid_0's binary_logloss: 0.140874
# [95]	valid_0's binary_logloss: 0.140705
# [96]	valid_0's binary_logloss: 0.140564
# [97]	valid_0's binary_logloss: 0.140134
# [98]	valid_0's binary_logloss: 0.140098
# [99]	valid_0's binary_logloss: 0.139863
# [100]	valid_0's binary_logloss: 0.139614
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.139614
#
# 정확도: 0.9459
# 정밀도: 0.9480
# AUC: 0.9432
